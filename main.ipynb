# %%
import os
import json
import pandas as pd
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import cred
import glob

client_credentials_manager = SpotifyClientCredentials(cred.client_id, cred.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

json_dir_name = '/Volumes/MUSIC/spotify_million_playlist_dataset/data'

json_pattern = os.path.join(json_dir_name, '*.json')
json_files = glob.glob(json_pattern)
json_files.sort()

# %%
track_uris = []

for index, js in enumerate(json_files):
    with open(os.path.join(json_dir_name, js), encoding='utf-8') as json_file:
        json_text = json.load(json_file)
        
        for j in range(len(json_text["playlists"])):
          for k in range(len(json_text["playlists"][j]["tracks"])):
            
            track_uri = json_text["playlists"][j]["tracks"][k]['track_uri']
            track_uris.append(track_uri)
            
        if (index + 1) % 50 == 0:
          print(f'I am on file {index + 1}')

list_uris = list(dict.fromkeys(track_uris))

# 25 minutes

# %%
# How many elements each
# list should have
n = 500 
  
# using list comprehension
chunks = [list_uris[i * n:(i + 1) * n] for i in range((len(list_uris) + n - 1) // n )] 

print(len(chunks))
print(chunks[0][0])
#20 seconds

# %%
def get_album_tracks(seed_tracks):
  print('Starting to get album tracks.')
  song_uris = []
  for i in range(len(seed_tracks)):
    try:
      track_info = sp.track(seed_tracks[i])
    except:
      continue
    album_uri = track_info['album']['uri']
    offset = 0

    while True:
      try:
        album_info = sp.album_tracks(album_uri, offset=offset)
      except:
        break
      if len(album_info['items']) == 0:
          break
      for j in range(len(album_info['items'])):
          if album_info['items'][j] == None:
              continue
          else:
              song_uris.append(album_info['items'][j]['uri'])  
      offset = offset + len(album_info['items'])
      time.sleep(0.001)

    if i == 249:
      print(f'I am on song 250 out of {len(seed_tracks)}')
    time.sleep(0.001)
    
  return list(set(song_uris))

def get_track_features(song_uris):
  print('Starting to get track features.')
  print(f'There are {len(song_uris)} to analyze.')
  dframe = pd.DataFrame(columns=['album_uri', 'artist_uri', 'artist_name', 'album_name', 'release_date', 'disc_number', 'popularity','track_number', 'duration', 'explicit', 'track_name', 'track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'intstrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'])
  for i in range(len(song_uris)):
    
    try:
      track_info = sp.track(song_uris[i])
    
      album_uri = track_info['album']['uri']
      artist_uri = track_info['artists'][0]['uri']
      artist_name = track_info['artists'][0]['name']
      album_name = track_info['album']['name']
      release_date = track_info['album']['release_date']
      disc_number = track_info['disc_number']
      popularity = track_info['popularity']
      track_number = track_info['track_number']
      duration = track_info['duration_ms']
      explicit = track_info['explicit']
      track_name = track_info['name']
      track_uri = track_info['uri']
      time.sleep(0.001)
    except:
      continue

    try:
      track_features = sp.audio_features(song_uris[i])
      
      danceability = track_features[0]['danceability']
      energy = track_features[0]['energy']
      key = track_features[0]['key']
      loudness = track_features[0]['loudness']
      mode = track_features[0]['mode']
      speechiness = track_features[0]['speechiness']
      acousticness = track_features[0]['acousticness']
      instrumentalness = track_features[0]['instrumentalness']
      liveness = track_features[0]['liveness']
      valence = track_features[0]['valence']
      tempo = track_features[0]['tempo']
      time_signature = track_features[0]['time_signature']
      time.sleep(0.001)
    except:
      continue
    
    observation = {
      'album_uri': album_uri,
      'artist_uri': artist_uri,
      'artist_name': artist_name,
      'album_name': album_name,
      'release_date': release_date,
      'disc_number': disc_number,
      'popularity': popularity,
      'track_number': track_number,
      'duration': duration,
      'explicit': explicit,
      'track_name': track_name,
      'track_uri': track_uri,
      'danceability': danceability,
      'energy': energy,
      'key': key,
      'loudness': loudness,
      'mode': mode,
      'speechiness': speechiness,
      'acousticness': acousticness,
      'instrumentalness': instrumentalness,
      'liveness': liveness,
      'valence': valence,
      'tempo': tempo,
      'time_signature': time_signature
    }
    
    dframe = dframe.append(pd.DataFrame([observation]))
    if (i + 1) % 2000 == 0:
      print(f'Currently on song {i + 1} out of {len(song_uris)}')
  return dframe

def make_df(index):
  print(f'Starting chunk {index + 1}')
  t_1 = time.time()
  chunk_uris = get_album_tracks(chunks[index])
  chunk_df = get_track_features(chunk_uris)
  t_2 = time.time()
  print(f'Completing chunk {index + 1} took {round((t_2 - t_1)/60, 2)} minutes.')
  return chunk_df

# %%
df = pd.DataFrame(columns=['album_uri', 'artist_uri', 'artist_name', 'album_name', 'release_date', 'disc_number', 'popularity','track_number', 'duration', 'explicit', 'track_name', 'track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'intstrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'])

# %%
# len(chunks) = 4525

indices = [i for i in range(349, 382)]

for index in indices:
  dfpiece = make_df(index)
  df = df.append(dfpiece)
  print(f'The dimensions of the data frame before droppping duplicates are {df.shape}')
  df = df.drop_duplicates(subset = "track_uri")
  print(f'The dimensions of the data frame after droppping duplicates are {df.shape}')
# Out:
# Starting chunk 350
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3737 to analyze.
# Currently on song 2000 out of 3737
# Completing chunk 350 took 14.96 minutes.
# The dimensions of the data frame before droppping duplicates are (3737, 25)
# The dimensions of the data frame after droppping duplicates are (3737, 25)
# Starting chunk 351
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4059 to analyze.
# Currently on song 2000 out of 4059
# Currently on song 4000 out of 4059
# Completing chunk 351 took 15.99 minutes.
# The dimensions of the data frame before droppping duplicates are (7796, 25)
# The dimensions of the data frame after droppping duplicates are (7785, 25)
# Starting chunk 352
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4935 to analyze.
# Currently on song 2000 out of 4935
# Currently on song 4000 out of 4935
# Completing chunk 352 took 18.97 minutes.
# The dimensions of the data frame before droppping duplicates are (12720, 25)
# The dimensions of the data frame after droppping duplicates are (12681, 25)
# Starting chunk 353
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5161 to analyze.
# Currently on song 2000 out of 5161
# Currently on song 4000 out of 5161
# Completing chunk 353 took 19.65 minutes.
# The dimensions of the data frame before droppping duplicates are (17842, 25)
# The dimensions of the data frame after droppping duplicates are (17794, 25)
# Starting chunk 354
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4699 to analyze.
# Currently on song 2000 out of 4699
# Currently on song 4000 out of 4699
# Completing chunk 354 took 18.16 minutes.
# The dimensions of the data frame before droppping duplicates are (22493, 25)
# The dimensions of the data frame after droppping duplicates are (22470, 25)
# Starting chunk 355
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4745 to analyze.
# Currently on song 2000 out of 4745
# Currently on song 4000 out of 4745
# Completing chunk 355 took 18.24 minutes.
# The dimensions of the data frame before droppping duplicates are (27214, 25)
# The dimensions of the data frame after droppping duplicates are (27160, 25)
# Starting chunk 356
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4704 to analyze.
# Currently on song 2000 out of 4704
# Currently on song 4000 out of 4704
# Completing chunk 356 took 18.14 minutes.
# The dimensions of the data frame before droppping duplicates are (31864, 25)
# The dimensions of the data frame after droppping duplicates are (31704, 25)
# Starting chunk 357
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 2075 to analyze.
# Currently on song 2000 out of 2075
# Completing chunk 357 took 9.44 minutes.
# The dimensions of the data frame before droppping duplicates are (33779, 25)
# The dimensions of the data frame after droppping duplicates are (33750, 25)
# Starting chunk 358
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4852 to analyze.
# Currently on song 2000 out of 4852
# Currently on song 4000 out of 4852
# Completing chunk 358 took 18.69 minutes.
# The dimensions of the data frame before droppping duplicates are (38602, 25)
# The dimensions of the data frame after droppping duplicates are (38498, 25)
# Starting chunk 359
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4240 to analyze.
# Currently on song 2000 out of 4240
# Currently on song 4000 out of 4240
# Completing chunk 359 took 16.64 minutes.
# The dimensions of the data frame before droppping duplicates are (42737, 25)
# The dimensions of the data frame after droppping duplicates are (42661, 25)
# Starting chunk 360
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5568 to analyze.
# Currently on song 2000 out of 5568
# Currently on song 4000 out of 5568
# Completing chunk 360 took 21.01 minutes.
# The dimensions of the data frame before droppping duplicates are (48229, 25)
# The dimensions of the data frame after droppping duplicates are (47384, 25)
# Starting chunk 361
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4357 to analyze.
# Currently on song 2000 out of 4357
# Currently on song 4000 out of 4357
# Completing chunk 361 took 16.92 minutes.
# The dimensions of the data frame before droppping duplicates are (51741, 25)
# The dimensions of the data frame after droppping duplicates are (51508, 25)
# Starting chunk 362
# Starting to get album tracks.
# I am on song 250 out of 500
# HTTP Error for GET to https://api.spotify.com/v1/tracks/0TFeqiu2zpZcgqaTaV9vMU with Params: {'market': None} returned 404 due to non existing id
# Starting to get track features.
# There are 4852 to analyze.
# Currently on song 2000 out of 4852
# Currently on song 4000 out of 4852
# Completing chunk 362 took 18.59 minutes.
# The dimensions of the data frame before droppping duplicates are (56360, 25)
# The dimensions of the data frame after droppping duplicates are (56205, 25)
# Starting chunk 363
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5196 to analyze.
# Currently on song 2000 out of 5196
# Currently on song 4000 out of 5196
# Completing chunk 363 took 19.74 minutes.
# The dimensions of the data frame before droppping duplicates are (61399, 25)
# The dimensions of the data frame after droppping duplicates are (61249, 25)
# Starting chunk 364
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4131 to analyze.
# Currently on song 2000 out of 4131
# Currently on song 4000 out of 4131
# Completing chunk 364 took 16.14 minutes.
# The dimensions of the data frame before droppping duplicates are (65380, 25)
# The dimensions of the data frame after droppping duplicates are (65140, 25)
# Starting chunk 365
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3454 to analyze.
# Currently on song 2000 out of 3454
# Completing chunk 365 took 13.95 minutes.
# The dimensions of the data frame before droppping duplicates are (68592, 25)
# The dimensions of the data frame after droppping duplicates are (68462, 25)
# Starting chunk 366
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4600 to analyze.
# Currently on song 2000 out of 4600
# Currently on song 4000 out of 4600
# Completing chunk 366 took 17.84 minutes.
# The dimensions of the data frame before droppping duplicates are (73060, 25)
# The dimensions of the data frame after droppping duplicates are (72740, 25)
# Starting chunk 367
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3305 to analyze.
# Currently on song 2000 out of 3305
# Completing chunk 367 took 13.5 minutes.
# The dimensions of the data frame before droppping duplicates are (76045, 25)
# The dimensions of the data frame after droppping duplicates are (75730, 25)
# Starting chunk 368
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4099 to analyze.
# Currently on song 2000 out of 4099
# Currently on song 4000 out of 4099
# Completing chunk 368 took 16.04 minutes.
# The dimensions of the data frame before droppping duplicates are (79829, 25)
# The dimensions of the data frame after droppping duplicates are (79623, 25)
# Starting chunk 369
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4859 to analyze.
# Currently on song 2000 out of 4859
# Currently on song 4000 out of 4859
# Completing chunk 369 took 18.64 minutes.
# The dimensions of the data frame before droppping duplicates are (84482, 25)
# The dimensions of the data frame after droppping duplicates are (83889, 25)
# Starting chunk 370
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4991 to analyze.
# Currently on song 2000 out of 4991
# Currently on song 4000 out of 4991
# Completing chunk 370 took 19.01 minutes.
# The dimensions of the data frame before droppping duplicates are (88880, 25)
# The dimensions of the data frame after droppping duplicates are (88556, 25)
# Starting chunk 371
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4199 to analyze.
# Currently on song 2000 out of 4199
# Currently on song 4000 out of 4199
# Completing chunk 371 took 16.39 minutes.
# The dimensions of the data frame before droppping duplicates are (92755, 25)
# The dimensions of the data frame after droppping duplicates are (92455, 25)
# Starting chunk 372
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4463 to analyze.
# Currently on song 2000 out of 4463
# Currently on song 4000 out of 4463
# Completing chunk 372 took 17.2 minutes.
# The dimensions of the data frame before droppping duplicates are (96918, 25)
# The dimensions of the data frame after droppping duplicates are (96612, 25)
# Starting chunk 373
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4221 to analyze.
# Currently on song 2000 out of 4221
# Currently on song 4000 out of 4221
# Completing chunk 373 took 16.38 minutes.
# The dimensions of the data frame before droppping duplicates are (100833, 25)
# The dimensions of the data frame after droppping duplicates are (100583, 25)
# Starting chunk 374
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4455 to analyze.
# Currently on song 2000 out of 4455
# Currently on song 4000 out of 4455
# Completing chunk 374 took 17.17 minutes.
# The dimensions of the data frame before droppping duplicates are (105038, 25)
# The dimensions of the data frame after droppping duplicates are (104693, 25)
# Starting chunk 375
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4672 to analyze.
# Currently on song 2000 out of 4672
# Currently on song 4000 out of 4672
# Completing chunk 375 took 17.85 minutes.
# The dimensions of the data frame before droppping duplicates are (109365, 25)
# The dimensions of the data frame after droppping duplicates are (109106, 25)
# Starting chunk 376
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4436 to analyze.
# Currently on song 2000 out of 4436
# Currently on song 4000 out of 4436
# Completing chunk 376 took 17.13 minutes.
# The dimensions of the data frame before droppping duplicates are (113542, 25)
# The dimensions of the data frame after droppping duplicates are (113183, 25)
# Starting chunk 377
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3576 to analyze.
# Currently on song 2000 out of 3576
# Completing chunk 377 took 14.27 minutes.
# The dimensions of the data frame before droppping duplicates are (116759, 25)
# The dimensions of the data frame after droppping duplicates are (116395, 25)
# Starting chunk 378
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4402 to analyze.
# Currently on song 2000 out of 4402
# Currently on song 4000 out of 4402
# Completing chunk 378 took 16.9 minutes.
# The dimensions of the data frame before droppping duplicates are (120797, 25)
# The dimensions of the data frame after droppping duplicates are (120416, 25)
# Starting chunk 379
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4377 to analyze.
# Currently on song 2000 out of 4377
# Currently on song 4000 out of 4377
# Completing chunk 379 took 17.33 minutes.
# The dimensions of the data frame before droppping duplicates are (124790, 25)
# The dimensions of the data frame after droppping duplicates are (124231, 25)
# Starting chunk 380
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5842 to analyze.
# Currently on song 2000 out of 5842
# Currently on song 4000 out of 5842
# Completing chunk 380 took 21.73 minutes.
# The dimensions of the data frame before droppping duplicates are (130073, 25)
# The dimensions of the data frame after droppping duplicates are (129691, 25)
# Starting chunk 381
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5304 to analyze.
# Currently on song 2000 out of 5304
# Currently on song 4000 out of 5304
# Completing chunk 381 took 20.0 minutes.
# The dimensions of the data frame before droppping duplicates are (134995, 25)
# The dimensions of the data frame after droppping duplicates are (134613, 25)
# Starting chunk 382
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3778 to analyze.
# Currently on song 2000 out of 3778
# Completing chunk 382 took 14.87 minutes.
# The dimensions of the data frame before droppping duplicates are (138391, 25)
# The dimensions of the data frame after droppping duplicates are (137884, 25)

# %%
df.to_csv(path_or_buf=r'/Users/iancurtis/Documents/coding/sta518_spotify/musicanalysis/data/chunks350-382.csv', index = False, index_label = False)
