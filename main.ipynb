# %%
import os
import json
import pandas as pd
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import cred

client_credentials_manager = SpotifyClientCredentials(cred.client_id, cred.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

path_to_json = '/Users/iancurtis/Documents/coding/sta518_spotify/musicanalysis/data/spotify_million_playlist_dataset/data'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# %%
track_uris = []


for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)
        
        for j in range(len(json_text["playlists"])):
          for k in range(len(json_text["playlists"][j]["tracks"])):
            
            track_uri = json_text["playlists"][j]["tracks"][k]['track_uri']
            track_uris.append(track_uri)
            
        if (index + 1) % 50 == 0:
          print(f'I am on file {index + 1}')

list_uris = list(dict.fromkeys(track_uris))

# 17 minutes

# %%
# How many elements each
# list should have
n = 500 
  
# using list comprehension
chunks = [list_uris[i * n:(i + 1) * n] for i in range((len(list_uris) + n - 1) // n )] 

df = pd.DataFrame(columns=['album_uri', 'artist_uri', 'artist_name', 'album_name', 'release_date', 'disc_number', 'popularity','track_number', 'duration', 'explicit', 'track_name', 'track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'intstrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'])

#33 seconds

# %%
def get_album_tracks(seed_tracks):
  print('Starting to get album tracks.')
  song_uris = []
  for i in range(len(seed_tracks)):
    try:
      track_info = sp.track(seed_tracks[i])
    except:
      continue
    album_uri = track_info['album']['uri']
    offset = 0

    while True:
      try:
        album_info = sp.album_tracks(album_uri, offset=offset)
      except:
        break
      if len(album_info['items']) == 0:
          break
      for j in range(len(album_info['items'])):
          if album_info['items'][j] == None:
              continue
          else:
              song_uris.append(album_info['items'][j]['uri'])  
      offset = offset + len(album_info['items'])
      time.sleep(0.001)

    if i == 249:
      print(f'I am on song 250 out of {len(seed_tracks)}')
    time.sleep(0.001)
    
  return list(set(song_uris))

def get_track_features(song_uris):
  print('Starting to get track features.')
  print(f'There are {len(song_uris)} to analyze.')
  dframe = pd.DataFrame(columns=['album_uri', 'artist_uri', 'artist_name', 'album_name', 'release_date', 'disc_number', 'popularity','track_number', 'duration', 'explicit', 'track_name', 'track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'intstrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'])
  for i in range(len(song_uris)):
    
    try:
      track_info = sp.track(song_uris[i])
    
      album_uri = track_info['album']['uri']
      artist_uri = track_info['artists'][0]['uri']
      artist_name = track_info['artists'][0]['name']
      album_name = track_info['album']['name']
      release_date = track_info['album']['release_date']
      disc_number = track_info['disc_number']
      popularity = track_info['popularity']
      track_number = track_info['track_number']
      duration = track_info['duration_ms']
      explicit = track_info['explicit']
      track_name = track_info['name']
      track_uri = track_info['uri']
      time.sleep(0.001)
    except:
      continue

    try:
      track_features = sp.audio_features(song_uris[i])
      
      danceability = track_features[0]['danceability']
      energy = track_features[0]['energy']
      key = track_features[0]['key']
      loudness = track_features[0]['loudness']
      mode = track_features[0]['mode']
      speechiness = track_features[0]['speechiness']
      acousticness = track_features[0]['acousticness']
      instrumentalness = track_features[0]['instrumentalness']
      liveness = track_features[0]['liveness']
      valence = track_features[0]['valence']
      tempo = track_features[0]['tempo']
      time_signature = track_features[0]['time_signature']
      time.sleep(0.001)
    except:
      continue
    
    observation = {
      'album_uri': album_uri,
      'artist_uri': artist_uri,
      'artist_name': artist_name,
      'album_name': album_name,
      'release_date': release_date,
      'disc_number': disc_number,
      'popularity': popularity,
      'track_number': track_number,
      'duration': duration,
      'explicit': explicit,
      'track_name': track_name,
      'track_uri': track_uri,
      'danceability': danceability,
      'energy': energy,
      'key': key,
      'loudness': loudness,
      'mode': mode,
      'speechiness': speechiness,
      'acousticness': acousticness,
      'instrumentalness': instrumentalness,
      'liveness': liveness,
      'valence': valence,
      'tempo': tempo,
      'time_signature': time_signature
    }
    
    dframe = dframe.append(pd.DataFrame([observation]))
    if (i + 1) % 2000 == 0:
      print(f'Currently on song {i + 1} out of {len(song_uris)}')
  return dframe

def make_df(index):
  print(f'Starting chunk {index + 1}')
  t_1 = time.time()
  chunk_uris = get_album_tracks(chunks[index])
  chunk_df = get_track_features(chunk_uris)
  t_2 = time.time()
  print(f'Completing chunk {index + 1} took {(t_2 - t_1)/60} minutes.')
  return chunk_df

# %%
# len(chunks) = 4525
# currently running indices 0 - 49 (which means the first 50 chunks)

indices = [i for i in range(0, 50)]

for index in indices:
  dfpiece = make_df(index)
  df = df.append(dfpiece)
  print(f'The dimensions of the data frame before droppping duplicates is {df.shape}')
  df = df.drop_duplicates(subset = "track_uri")
  print(f'The dimensions of the data frame after droppping duplicates is {df.shape}')
# Out:
# Starting chunk 1
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4925 to analyze.
# Currently on song 2000 out of 4925
# Currently on song 4000 out of 4925
# Completing chunk 1 took 18.603561635812124 minutes.
# The dimensions of the data frame before droppping duplicates is (4925, 25)
# The dimensions of the data frame after droppping duplicates is (4925, 25)
# Starting chunk 2
# Starting to get album tracks.
# HTTP Error for GET to https://api.spotify.com/v1/tracks/4WHjf37BBXUo3WYBmJPdoU with Params: {'market': None} returned 404 due to non existing id
# I am on song 250 out of 500
# Starting to get track features.
# There are 5502 to analyze.
# Currently on song 2000 out of 5502
# Currently on song 4000 out of 5502
# Completing chunk 2 took 20.48076589902242 minutes.
# The dimensions of the data frame before droppping duplicates is (10427, 25)
# The dimensions of the data frame after droppping duplicates is (10266, 25)
# Starting chunk 3
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4032 to analyze.
# Currently on song 2000 out of 4032
# Currently on song 4000 out of 4032
# Completing chunk 3 took 15.680212632815044 minutes.
# The dimensions of the data frame before droppping duplicates is (14297, 25)
# The dimensions of the data frame after droppping duplicates is (13968, 25)
# Starting chunk 4
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5495 to analyze.
# Currently on song 2000 out of 5495
# Currently on song 4000 out of 5495
# Completing chunk 4 took 20.363466465473174 minutes.
# The dimensions of the data frame before droppping duplicates is (19463, 25)
# The dimensions of the data frame after droppping duplicates is (18943, 25)
# Starting chunk 5
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4801 to analyze.
# Currently on song 2000 out of 4801
# Currently on song 4000 out of 4801
# Completing chunk 5 took 18.173954117298127 minutes.
# The dimensions of the data frame before droppping duplicates is (23744, 25)
# The dimensions of the data frame after droppping duplicates is (23537, 25)
# Starting chunk 6
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5142 to analyze.
# Currently on song 2000 out of 5142
# Currently on song 4000 out of 5142
# Completing chunk 6 took 19.380464883645377 minutes.
# The dimensions of the data frame before droppping duplicates is (28678, 25)
# The dimensions of the data frame after droppping duplicates is (27872, 25)
# Starting chunk 7
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4097 to analyze.
# Currently on song 2000 out of 4097
# Currently on song 4000 out of 4097
# Completing chunk 7 took 15.89027698437373 minutes.
# The dimensions of the data frame before droppping duplicates is (31968, 25)
# The dimensions of the data frame after droppping duplicates is (31329, 25)
# Starting chunk 8
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4763 to analyze.
# Currently on song 2000 out of 4763
# Currently on song 4000 out of 4763
# Completing chunk 8 took 18.043895069758097 minutes.
# The dimensions of the data frame before droppping duplicates is (36092, 25)
# The dimensions of the data frame after droppping duplicates is (35406, 25)
# Starting chunk 9
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3632 to analyze.
# Currently on song 2000 out of 3632
# Completing chunk 9 took 14.362747418880463 minutes.
# The dimensions of the data frame before droppping duplicates is (39038, 25)
# The dimensions of the data frame after droppping duplicates is (38416, 25)
# Starting chunk 10
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5770 to analyze.
# Currently on song 2000 out of 5770
# Currently on song 4000 out of 5770
# Completing chunk 10 took 21.274401950836182 minutes.
# The dimensions of the data frame before droppping duplicates is (44185, 25)
# The dimensions of the data frame after droppping duplicates is (43175, 25)
# Starting chunk 11
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4432 to analyze.
# Currently on song 2000 out of 4432
# Currently on song 4000 out of 4432
# Completing chunk 11 took 16.994588283697762 minutes.
# The dimensions of the data frame before droppping duplicates is (47607, 25)
# The dimensions of the data frame after droppping duplicates is (46856, 25)
# Starting chunk 12
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4968 to analyze.
# Currently on song 2000 out of 4968
# Currently on song 4000 out of 4968
# Completing chunk 12 took 18.72629161675771 minutes.
# The dimensions of the data frame before droppping duplicates is (51824, 25)
# The dimensions of the data frame after droppping duplicates is (50625, 25)
# Starting chunk 13
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3965 to analyze.
# Currently on song 2000 out of 3965
# Completing chunk 13 took 15.479627199967702 minutes.
# The dimensions of the data frame before droppping duplicates is (54590, 25)
# The dimensions of the data frame after droppping duplicates is (53366, 25)
# Starting chunk 14
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5447 to analyze.
# Currently on song 2000 out of 5447
# Currently on song 4000 out of 5447
# Completing chunk 14 took 20.26223426659902 minutes.
# The dimensions of the data frame before droppping duplicates is (58811, 25)
# The dimensions of the data frame after droppping duplicates is (57738, 25)
# Starting chunk 15
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5594 to analyze.
# Currently on song 2000 out of 5594
# Currently on song 4000 out of 5594
# Completing chunk 15 took 20.701991216341654 minutes.
# The dimensions of the data frame before droppping duplicates is (63332, 25)
# The dimensions of the data frame after droppping duplicates is (62164, 25)
# Starting chunk 16
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4745 to analyze.
# Currently on song 2000 out of 4745
# Currently on song 4000 out of 4745
# Completing chunk 16 took 18.020968401432036 minutes.
# The dimensions of the data frame before droppping duplicates is (66908, 25)
# The dimensions of the data frame after droppping duplicates is (65431, 25)
# Starting chunk 17
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3461 to analyze.
# Currently on song 2000 out of 3461
# Completing chunk 17 took 23.75881515343984 minutes.
# The dimensions of the data frame before droppping duplicates is (68891, 25)
# The dimensions of the data frame after droppping duplicates is (67918, 25)
# Starting chunk 18
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4350 to analyze.
# Currently on song 2000 out of 4350
# Currently on song 4000 out of 4350
# Completing chunk 18 took 16.52983849843343 minutes.
# The dimensions of the data frame before droppping duplicates is (72267, 25)
# The dimensions of the data frame after droppping duplicates is (70923, 25)
# Starting chunk 19
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5097 to analyze.
# Currently on song 2000 out of 5097
# Currently on song 4000 out of 5097
# Completing chunk 19 took 19.129427830378216 minutes.
# The dimensions of the data frame before droppping duplicates is (76020, 25)
# The dimensions of the data frame after droppping duplicates is (74425, 25)
# Starting chunk 20
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4917 to analyze.
# Currently on song 2000 out of 4917
# Currently on song 4000 out of 4917
# Completing chunk 20 took 18.857945811748504 minutes.
# The dimensions of the data frame before droppping duplicates is (79334, 25)
# The dimensions of the data frame after droppping duplicates is (78338, 25)
# Starting chunk 21
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5830 to analyze.
# Currently on song 2000 out of 5830
# Currently on song 4000 out of 5830
# Completing chunk 21 took 74.23477909962337 minutes.
# The dimensions of the data frame before droppping duplicates is (84161, 25)
# The dimensions of the data frame after droppping duplicates is (82393, 25)
# Starting chunk 22
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4605 to analyze.
# Currently on song 2000 out of 4605
# Currently on song 4000 out of 4605
# Completing chunk 22 took 17.729442012310027 minutes.
# The dimensions of the data frame before droppping duplicates is (86995, 25)
# The dimensions of the data frame after droppping duplicates is (85414, 25)
# Starting chunk 23
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4218 to analyze.
# Currently on song 2000 out of 4218
# Currently on song 4000 out of 4218
# Completing chunk 23 took 16.455542846520743 minutes.
# The dimensions of the data frame before droppping duplicates is (89631, 25)
# The dimensions of the data frame after droppping duplicates is (88667, 25)
# Starting chunk 24
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4999 to analyze.
# Currently on song 2000 out of 4999
# Currently on song 4000 out of 4999
# Completing chunk 24 took 18.814822097619373 minutes.
# The dimensions of the data frame before droppping duplicates is (93666, 25)
# The dimensions of the data frame after droppping duplicates is (92418, 25)
# Starting chunk 25
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4982 to analyze.
# Currently on song 2000 out of 4982
# Currently on song 4000 out of 4982
# Completing chunk 25 took 18.830702980359394 minutes.
# The dimensions of the data frame before droppping duplicates is (97400, 25)
# The dimensions of the data frame after droppping duplicates is (95520, 25)
# Starting chunk 26
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4937 to analyze.
# Currently on song 2000 out of 4937
# Currently on song 4000 out of 4937
# Completing chunk 26 took 18.655469147364297 minutes.
# The dimensions of the data frame before droppping duplicates is (100457, 25)
# The dimensions of the data frame after droppping duplicates is (99034, 25)
# Starting chunk 27
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 2225 to analyze.
# Currently on song 2000 out of 2225
# Completing chunk 27 took 9.695303805669148 minutes.
# The dimensions of the data frame before droppping duplicates is (101259, 25)
# The dimensions of the data frame after droppping duplicates is (100367, 25)
# Starting chunk 28
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4679 to analyze.
# Currently on song 2000 out of 4679
# Currently on song 4000 out of 4679
# Completing chunk 28 took 18.01939058303833 minutes.
# The dimensions of the data frame before droppping duplicates is (105045, 25)
# The dimensions of the data frame after droppping duplicates is (103410, 25)
# Starting chunk 29
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5289 to analyze.
# Currently on song 2000 out of 5289
# Currently on song 4000 out of 5289
# Completing chunk 29 took 19.94424209992091 minutes.
# The dimensions of the data frame before droppping duplicates is (108699, 25)
# The dimensions of the data frame after droppping duplicates is (107287, 25)
# Starting chunk 30
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3902 to analyze.
# Currently on song 2000 out of 3902
# Completing chunk 30 took 15.17985771894455 minutes.
# The dimensions of the data frame before droppping duplicates is (111189, 25)
# The dimensions of the data frame after droppping duplicates is (109935, 25)
# Starting chunk 31
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3981 to analyze.
# Currently on song 2000 out of 3981
# Completing chunk 31 took 15.485574932893117 minutes.
# The dimensions of the data frame before droppping duplicates is (113916, 25)
# The dimensions of the data frame after droppping duplicates is (111840, 25)
# Starting chunk 32
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4852 to analyze.
# Currently on song 2000 out of 4852
# Currently on song 4000 out of 4852
# Completing chunk 32 took 18.345878752072654 minutes.
# The dimensions of the data frame before droppping duplicates is (116692, 25)
# The dimensions of the data frame after droppping duplicates is (114718, 25)
# Starting chunk 33
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5055 to analyze.
# Currently on song 2000 out of 5055
# Currently on song 4000 out of 5055
# Completing chunk 33 took 19.01271731853485 minutes.
# The dimensions of the data frame before droppping duplicates is (119773, 25)
# The dimensions of the data frame after droppping duplicates is (117553, 25)
# Starting chunk 34
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3709 to analyze.
# Currently on song 2000 out of 3709
# Completing chunk 34 took 14.634509150187174 minutes.
# The dimensions of the data frame before droppping duplicates is (121262, 25)
# The dimensions of the data frame after droppping duplicates is (120084, 25)
# Starting chunk 35
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 2888 to analyze.
# Currently on song 2000 out of 2888
# Completing chunk 35 took 12.669116199016571 minutes.
# The dimensions of the data frame before droppping duplicates is (122971, 25)
# The dimensions of the data frame after droppping duplicates is (121792, 25)
# Starting chunk 36
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3579 to analyze.
# Currently on song 2000 out of 3579
# Completing chunk 36 took 14.238615437348683 minutes.
# The dimensions of the data frame before droppping duplicates is (125371, 25)
# The dimensions of the data frame after droppping duplicates is (124566, 25)
# Starting chunk 37
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3644 to analyze.
# Currently on song 2000 out of 3644
# Completing chunk 37 took 14.504071700572968 minutes.
# The dimensions of the data frame before droppping duplicates is (128209, 25)
# The dimensions of the data frame after droppping duplicates is (127514, 25)
# Starting chunk 38
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4427 to analyze.
# Currently on song 2000 out of 4427
# Currently on song 4000 out of 4427
# Completing chunk 38 took 17.45009568532308 minutes.
# The dimensions of the data frame before droppping duplicates is (131940, 25)
# The dimensions of the data frame after droppping duplicates is (130630, 25)
# Starting chunk 39
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3807 to analyze.
# Currently on song 2000 out of 3807
# Completing chunk 39 took 15.188520753383637 minutes.
# The dimensions of the data frame before droppping duplicates is (134437, 25)
# The dimensions of the data frame after droppping duplicates is (132834, 25)
# Starting chunk 40
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4734 to analyze.
# Currently on song 2000 out of 4734
# Currently on song 4000 out of 4734
# Completing chunk 40 took 18.049173831939697 minutes.
# The dimensions of the data frame before droppping duplicates is (137568, 25)
# The dimensions of the data frame after droppping duplicates is (136085, 25)
# Starting chunk 41
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5196 to analyze.
# Currently on song 2000 out of 5196
# Currently on song 4000 out of 5196
# Completing chunk 41 took 20.424096131324767 minutes.
# The dimensions of the data frame before droppping duplicates is (141277, 25)
# The dimensions of the data frame after droppping duplicates is (139437, 25)
# Starting chunk 42
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5318 to analyze.
# Currently on song 2000 out of 5318
# Currently on song 4000 out of 5318
# Completing chunk 42 took 20.002067053318022 minutes.
# The dimensions of the data frame before droppping duplicates is (144755, 25)
# The dimensions of the data frame after droppping duplicates is (143047, 25)
# Starting chunk 43
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3371 to analyze.
# Currently on song 2000 out of 3371
# Completing chunk 43 took 13.548282066980997 minutes.
# The dimensions of the data frame before droppping duplicates is (146418, 25)
# The dimensions of the data frame after droppping duplicates is (145257, 25)
# Starting chunk 44
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4749 to analyze.
# Currently on song 2000 out of 4749
# Currently on song 4000 out of 4749
# Completing chunk 44 took 18.422322082519532 minutes.
# The dimensions of the data frame before droppping duplicates is (150005, 25)
# The dimensions of the data frame after droppping duplicates is (148456, 25)
# Starting chunk 45
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 3494 to analyze.
# Currently on song 2000 out of 3494
# Completing chunk 45 took 14.23523216644923 minutes.
# The dimensions of the data frame before droppping duplicates is (151949, 25)
# The dimensions of the data frame after droppping duplicates is (150787, 25)
# Starting chunk 46
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5253 to analyze.
# Currently on song 2000 out of 5253
# Currently on song 4000 out of 5253
# Completing chunk 46 took 19.843745601177215 minutes.
# The dimensions of the data frame before droppping duplicates is (156039, 25)
# The dimensions of the data frame after droppping duplicates is (154230, 25)
# Starting chunk 47
# Starting to get album tracks.
# I am on song 250 out of 500
# HTTP Error for GET to https://api.spotify.com/v1/tracks/2aeURFmfpaB6NGp09TCdzi with Params: {'market': None} returned 404 due to non existing id
# Starting to get track features.
# There are 4218 to analyze.
# Currently on song 2000 out of 4218
# Currently on song 4000 out of 4218
# Completing chunk 47 took 16.470179716746014 minutes.
# The dimensions of the data frame before droppping duplicates is (158448, 25)
# The dimensions of the data frame after droppping duplicates is (157212, 25)
# Starting chunk 48
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4817 to analyze.
# Currently on song 2000 out of 4817
# Currently on song 4000 out of 4817
# Completing chunk 48 took 18.478483800093333 minutes.
# The dimensions of the data frame before droppping duplicates is (162029, 25)
# The dimensions of the data frame after droppping duplicates is (160697, 25)
# Starting chunk 49
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 4622 to analyze.
# Currently on song 2000 out of 4622
# Currently on song 4000 out of 4622
# Completing chunk 49 took 17.863225396474203 minutes.
# The dimensions of the data frame before droppping duplicates is (165319, 25)
# The dimensions of the data frame after droppping duplicates is (164063, 25)
# Starting chunk 50
# Starting to get album tracks.
# I am on song 250 out of 500
# Starting to get track features.
# There are 5164 to analyze.
# Currently on song 2000 out of 5164
# Currently on song 4000 out of 5164
# Completing chunk 50 took 19.634316849708558 minutes.
# The dimensions of the data frame before droppping duplicates is (169227, 25)
# The dimensions of the data frame after droppping duplicates is (167228, 25)

# %%
df.to_csv(path_or_buf=r'/Users/iancurtis/Documents/coding/sta518_spotify/musicanalysis/data/chunk_1.csv', index = False, index_label = False)
